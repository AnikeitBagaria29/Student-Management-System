# %% [markdown]
# Experiment 1: Starting with Python

# %% [markdown]
# Question 1

# %%
import sys

print("Python is installed in the device.")
print("Installed Version is ", sys.version)
# Out:
# Python is installed in the device.
# Installed Version is  3.14.6 (tags/v3.14.6:c63aec6, Jun 10 2026, 10:26:10) [MSC v.1944 64 bit (AMD64)]

# %% [markdown]
# Question 2. Write Python programs to print strings in the given manner.

# %%
# 2a
print("Hello World")

# 2b
print("Hello")
print("World")

# 2c
print("Hello\nWorld")

# 2d
print("Anikeit's Date of Birth is 29\01\2003")
# Out:
# Hello World
# Hello
# World
# Hello
# World
# Anikeit's Date of Birth is 293

# %% [markdown]
# Question 3. Declare a string variable x and assign it string value Hello World. Print the value of x

# %%
x = "Hello World"
print(x)
# Out:
# Hello World

# %% [markdown]
# Question 4. Take different data types and print values using the print() function.

# %%
integer_value = 100
float_value = 1.23
string_value = "Hello World"
boolean_value = False
list_value = [11, 12, 13]

print("Integer Value is: ", integer_value)
print("Float Value is:", float_value)
print("String Value is:", string_value)
print("Boolean Value is:", boolean_value)
print("List Value is:", list_value)
# Out:
# Integer Value is:  100
# Float Value is: 1.23
# String Value is: Hello World
# Boolean Value is: False
# List Value is: [11, 12, 13]

# %% [markdown]
# Question 5. Take two variables a and b. Assign your first name and last name. Print your full name by adding both.

# %%
a = "Anikeit"
b = "Bagaria"
fullname = a + " " + b
print("My Full Name is:", fullname)
# Out:
# My Full Name is: Anikeit Bagaria

# %% [markdown]
# Question 6. Declare firstname, lastname and nickname. Print as: FirstName (Nickname) LastName

# %%
firstname = "Anikeit"
lastname = "Bagaria"
nickname = "anik"

print(f"{firstname} ({nickname}) {lastname}")
# Out:
# Anikeit (anik) Bagaria

# %% [markdown]
# Question 7. Declare and assign suitable variables, then print the details in the required format.

# %% [markdown]
# **Variable:** One can visualize as a container. Its value can change during the program execution
# ![image.png](attachment:50cc1cc7-92e4-475d-8c0f-e723cef4e434.png)

# %%
name = "Anikeit Bagaria"
sap_id = "590040405"
dateofbirth = "29-Jan-2003"
address_line_1 = "UPES"
address_line_2 = "Kandoli Campus"
pincode = "248007"
programme = "CSE Data Science"
semester = 1

print("Name:", name)
print("SAP ID:", sap_id)
print("Date of Birth:", dateofbirth)
print("Address:", address_line_1)
print(address_line_2)
print("Pincode:", pincode)
print("Programme:", programme)
print("Semester:", semester)
# Out:
# Name: Anikeit Bagaria
# SAP ID: 590040405
# Date of Birth: 29-Jan-2003
# Address: UPES
# Kandoli Campus
# Pincode: 248007
# Programme: CSE Data Science
# Semester: 1
